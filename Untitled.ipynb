# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
df1 = pd.read_csv('train.csv')
df2 = pd.read_csv('test.csv')

# %%
df1.head()
# Out:
#        Id  satisfaction  Gender   Customer Type  Age   Type of Travel  \
# 0   86347     satisfied    Male  Loyal Customer   50  Business travel
# 1  115822     satisfied    Male  Loyal Customer   51  Business travel
# 2   16351  dissatisfied    Male  Loyal Customer   14  Personal Travel
# 3  107284     satisfied  Female  Loyal Customer   52  Business travel
# 4    5788  dissatisfied  Female  Loyal Customer   26  Personal Travel
#
#       Class  Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0  Business             1548             5                                  5
# 1  Business             4020             5                                  5
# 2       Eco             2328             2                                  5
# 3  Business             3761             2                                  2
# 4       Eco             3348             1                                  5
#
#    ...  Online support  Ease of Online booking  On-board service  \
# ...

# %%
df2.head()
# Out:
#        Id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   46587  Female  disloyal Customer   22  Business travel       Eco
# 1  124920    Male     Loyal Customer   25  Business travel  Business
# 2   18490  Female     Loyal Customer   21  Personal Travel       Eco
# 3   78644  Female     Loyal Customer   34  Business travel  Business
# 4   92713    Male     Loyal Customer   39  Business travel  Business
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0             2354             2                                  2
# 1             2855             2                                  2
# 2             1250             4                                  4
# 3               95             1                                  2
# 4             3276             5                                  2
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# 0               2  ...               2                       2
# ...

# %%
df1.isnull().sum()
# Out:
# Id                                     0
# satisfaction                           0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# ...

# %%
min= df1["Arrival Delay in Minutes"].min()
max= df1["Arrival Delay in Minutes"].max()
print(min,max)
# Out:
# 0.0 1584.0

# %% [markdown]
# #### As we can see the only column that has any null value is "Arrival Delay in Minutes"
# Here we can handle these null values by either mean or median. Because of long delays in some cases this column has some extreme values so we will be using median here as mean is affected much more by values compared to median.

# %%
df1['Arrival Delay in Minutes']=df1['Arrival Delay in Minutes'].fillna(df1['Arrival Delay in Minutes'].median())

# %%
df1.isnull().sum()
# Out:
# Id                                   0
# satisfaction                         0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %% [markdown]
# #### Now we need to change the categorical features of some columns to numerical features for ease of our model

# %% [markdown]
# We will use label encoding for "Satisfaction" and "Gender" as they have only two possible values

# %%
print(df1['satisfaction'].unique())
print(df1['Gender'].unique())
# Out:
# ['satisfied' 'dissatisfied']
# ['Male' 'Female']

# %%
df1['Gender']=df1['Gender'].map({'Male': 1, 'Female': 0})

# %%
df1.head()
# Out:
#        Id  satisfaction  Gender   Customer Type  Age   Type of Travel  \
# 0   86347     satisfied       1  Loyal Customer   50  Business travel
# 1  115822     satisfied       1  Loyal Customer   51  Business travel
# 2   16351  dissatisfied       1  Loyal Customer   14  Personal Travel
# 3  107284     satisfied       0  Loyal Customer   52  Business travel
# 4    5788  dissatisfied       0  Loyal Customer   26  Personal Travel
#
#       Class  Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0  Business             1548             5                                  5
# 1  Business             4020             5                                  5
# 2       Eco             2328             2                                  5
# 3  Business             3761             2                                  2
# 4       Eco             3348             1                                  5
#
#    ...  Online support  Ease of Online booking  On-board service  \
# ...

# %% [markdown]
# We will use one-hot encoding for features that have more than two possible values

# %%
df1 = pd.get_dummies(df1, columns=['Customer Type', 'Type of Travel', 'Class'], drop_first=True)

# %%
df1= df1.apply(lambda col: col.astype(int) if col.dtype == "bool" else col)

# %%
df1.head()
# Out:
#        Id  satisfaction  Gender  Age  Flight Distance  Seat comfort  \
# 0   86347     satisfied       1   50             1548             5
# 1  115822     satisfied       1   51             4020             5
# 2   16351  dissatisfied       1   14             2328             2
# 3  107284     satisfied       0   52             3761             2
# 4    5788  dissatisfied       0   26             3348             1
#
#    Departure/Arrival time convenient  Food and drink  Gate location  \
# 0                                  5               5              5
# 1                                  5               5              5
# 2                                  5               1              4
# 3                                  2               2              2
# 4                                  5               0              3
#
#    Inflight wifi service  ...  Baggage handling  Checkin service  Cleanliness  \
# ...

# %%
df1.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Flight Distance'}>,
#         <Axes: title={'center': 'Seat comfort'}>],
#        [<Axes: title={'center': 'Departure/Arrival time convenient'}>,
#         <Axes: title={'center': 'Food and drink'}>,
#         <Axes: title={'center': 'Gate location'}>,
#         <Axes: title={'center': 'Inflight wifi service'}>,
#         <Axes: title={'center': 'Inflight entertainment'}>],
#        [<Axes: title={'center': 'Online support'}>,
#         <Axes: title={'center': 'Ease of Online booking'}>,
#         <Axes: title={'center': 'On-board service'}>,
#         <Axes: title={'center': 'Leg room service'}>,
#         <Axes: title={'center': 'Baggage handling'}>],
#        [<Axes: title={'center': 'Checkin service'}>,
#         <Axes: title={'center': 'Cleanliness'}>,
#         <Axes: title={'center': 'Online boarding'}>,
# ...

# %%
df1.head()
# Out:
#        Id  satisfaction  Gender  Age  Flight Distance  Seat comfort  \
# 0   86347     satisfied       1   50             1548             5
# 1  115822     satisfied       1   51             4020             5
# 2   16351  dissatisfied       1   14             2328             2
# 3  107284     satisfied       0   52             3761             2
# 4    5788  dissatisfied       0   26             3348             1
#
#    Departure/Arrival time convenient  Food and drink  Gate location  \
# 0                                  5               5              5
# 1                                  5               5              5
# 2                                  5               1              4
# 3                                  2               2              2
# 4                                  5               0              3
#
#    Inflight wifi service  ...  Baggage handling  Checkin service  Cleanliness  \
# ...

# %%
X = df1.drop(['satisfaction'], axis=1)
y = df1['satisfaction']

# %% [markdown]
# #### Now we initialize and train the decision tree with the training dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
tree=DecisionTreeClassifier(random_state=42)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
tree.fit(X,y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
prediction=tree.predict(X_test)

# %%
prediction
# Out:
# array(['dissatisfied', 'satisfied', 'dissatisfied', ..., 'satisfied',
#        'satisfied', 'satisfied'], dtype=object)

# %%
rf=RandomForestClassifier()
rf.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
df2.isnull().sum()
# Out:
# Id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
df2['Gender']=df2['Gender'].map({'Male': 1, 'Female': 0})

# %%
df2 = pd.get_dummies(df2, columns=['Customer Type', 'Type of Travel', 'Class'], drop_first=True)

# %%
df2= df2.apply(lambda col: col.astype(int) if col.dtype == "bool" else col)

# %%
X_test=df2.copy()

# %%
test_predictions = tree.predict(X_test)

# %%
test_predictions_2=rf.predict(X_test)

# %%
predictions_2=tree.predict(X_test)

# %%
submission_2= pd.DataFrame({'ID' : df2['Id'],'satisfaction' :predictions_2})

# %%
submission= pd.DataFrame({'ID' : df2['Id'], 'satisfatction' : test_predictions})

# %%
submission_5= pd.DataFrame({'ID' : df2['Id'],'satisfaction' :test_predictions_2})

# %%
submission_5
# Out:
#            ID  satisfaction
# 0       46587  dissatisfied
# 1      124920     satisfied
# 2       18490     satisfied
# 3       78644  dissatisfied
# 4       92713     satisfied
# ...       ...           ...
# 12944  125624     satisfied
# 12945   88138     satisfied
# 12946   86801  dissatisfied
# 12947   78439  dissatisfied
# 12948   76852  dissatisfied
#
# [12949 rows x 2 columns]

# %%
filename="Tensor_Titans_1.csv"
submission.to_csv(filename, index= False)
print('Saved File' + filename)
# Out:
# Saved FileTensor_Titans_1.csv

# %%
filename="Tensor_Titans_2.csv"
submission_2.to_csv(filename, index= False)
print('Saved File' + filename)
# Out:
# Saved FileTensor_Titans_2.csv

# %%
filename="Tensor_Titans_5.csv"
submission_5.to_csv(filename, index= False)
print('Saved File' + filename)
# Out:
# Saved FileTensor_Titans_5.csv
