# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
df1 = pd.read_csv('train.csv')
df2 = pd.read_csv('test.csv')

# %%
df1.head()
# Out:
#        Id  satisfaction  Gender   Customer Type  Age   Type of Travel  \
# 0   86347     satisfied    Male  Loyal Customer   50  Business travel
# 1  115822     satisfied    Male  Loyal Customer   51  Business travel
# 2   16351  dissatisfied    Male  Loyal Customer   14  Personal Travel
# 3  107284     satisfied  Female  Loyal Customer   52  Business travel
# 4    5788  dissatisfied  Female  Loyal Customer   26  Personal Travel
#
#       Class  Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0  Business             1548             5                                  5
# 1  Business             4020             5                                  5
# 2       Eco             2328             2                                  5
# 3  Business             3761             2                                  2
# 4       Eco             3348             1                                  5
#
#    ...  Online support  Ease of Online booking  On-board service  \
# ...

# %%
df1.isnull().sum()
# Out:
# Id                                     0
# satisfaction                           0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# ...

# %%
df1['Arrival Delay in Minutes']=df1['Arrival Delay in Minutes'].fillna(df1['Arrival Delay in Minutes'].median())

# %%
df1.isnull().sum()
# Out:
# Id                                   0
# satisfaction                         0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
print(df1['satisfaction'].unique())
print(df1['Gender'].unique())
print(df1['Customer Type'].unique())
print(df1['Type of Travel'].unique())
print(df1['Class'].unique())
# Out:
# ['satisfied' 'dissatisfied']
# ['Male' 'Female']
# ['Loyal Customer' 'disloyal Customer']
# ['Business travel' 'Personal Travel']
# ['Business' 'Eco' 'Eco Plus']

# %%
df1['Gender']=df1['Gender'].map({'Male': 1, 'Female': 0})
df1['Customer Type']=df1['Customer Type'].map({'Loyal Customer': 1, 'disloyal Customer': 0})
df1['Type of Travel']=df1['Type of Travel'].map({'Business travel': 1, 'Personal Travel': 0})

# %%
df1.head()
# Out:
#        Id  satisfaction  Gender  Customer Type  Age  Type of Travel     Class  \
# 0   86347     satisfied       1              1   50               1  Business
# 1  115822     satisfied       1              1   51               1  Business
# 2   16351  dissatisfied       1              1   14               0       Eco
# 3  107284     satisfied       0              1   52               1  Business
# 4    5788  dissatisfied       0              1   26               0       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  ...  \
# 0             1548             5                                  5  ...
# 1             4020             5                                  5  ...
# 2             2328             2                                  5  ...
# 3             3761             2                                  2  ...
# 4             3348             1                                  5  ...
#
# ...

# %%
df1 = pd.get_dummies(df1, columns=['Class'])

# %%
df1.head()
# Out:
#        Id  satisfaction  Gender  Customer Type  Age  Type of Travel  \
# 0   86347     satisfied       1              1   50               1
# 1  115822     satisfied       1              1   51               1
# 2   16351  dissatisfied       1              1   14               0
# 3  107284     satisfied       0              1   52               1
# 4    5788  dissatisfied       0              1   26               0
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0             1548             5                                  5
# 1             4020             5                                  5
# 2             2328             2                                  5
# 3             3761             2                                  2
# 4             3348             1                                  5
#
#    Food and drink  ...  Leg room service  Baggage handling  Checkin service  \
# ...

# %%
df1= df1.apply(lambda col: col.astype(int) if col.dtype == "bool" else col)

# %%
df1.head()
# Out:
#        Id  satisfaction  Gender  Customer Type  Age  Type of Travel  \
# 0   86347     satisfied       1              1   50               1
# 1  115822     satisfied       1              1   51               1
# 2   16351  dissatisfied       1              1   14               0
# 3  107284     satisfied       0              1   52               1
# 4    5788  dissatisfied       0              1   26               0
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0             1548             5                                  5
# 1             4020             5                                  5
# 2             2328             2                                  5
# 3             3761             2                                  2
# 4             3348             1                                  5
#
#    Food and drink  ...  Leg room service  Baggage handling  Checkin service  \
# ...

# %%
df1.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'Customer Type'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Type of Travel'}>],
#        [<Axes: title={'center': 'Flight Distance'}>,
#         <Axes: title={'center': 'Seat comfort'}>,
#         <Axes: title={'center': 'Departure/Arrival time convenient'}>,
#         <Axes: title={'center': 'Food and drink'}>,
#         <Axes: title={'center': 'Gate location'}>],
#        [<Axes: title={'center': 'Inflight wifi service'}>,
#         <Axes: title={'center': 'Inflight entertainment'}>,
#         <Axes: title={'center': 'Online support'}>,
#         <Axes: title={'center': 'Ease of Online booking'}>,
#         <Axes: title={'center': 'On-board service'}>],
#        [<Axes: title={'center': 'Leg room service'}>,
#         <Axes: title={'center': 'Baggage handling'}>,
#         <Axes: title={'center': 'Checkin service'}>,
# ...

# %%
X = df1.drop(['satisfaction','Gender','Id','Age','Class_Business','Class_Eco','Class_Eco Plus','Arrival Delay in Minutes','Departure/Arrival time convenient','Online boarding','Cleanliness','Checkin service','Leg room service','Ease of Online booking','Online support','On-board service'], axis=1)
y = df1['satisfaction']

# %%
X
# Out:
#         Customer Type  Type of Travel  Flight Distance  Seat comfort  \
# 0                   1               1             1548             5
# 1                   1               1             4020             5
# 2                   1               0             2328             2
# 3                   1               1             3761             2
# 4                   1               0             3348             1
# ...               ...             ...              ...           ...
# 116887              1               1              440             4
# 116888              1               1             5000             4
# 116889              1               1             4826             1
# 116890              1               0             1181             4
# 116891              1               1             4001             4
#
#         Food and drink  Gate location  Inflight wifi service  \
# 0                    5              5                      4
# ...

# %%
tree=DecisionTreeClassifier(random_state=42)
tree.fit(X,y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
df2.head()
# Out:
#        Id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   46587  Female  disloyal Customer   22  Business travel       Eco
# 1  124920    Male     Loyal Customer   25  Business travel  Business
# 2   18490  Female     Loyal Customer   21  Personal Travel       Eco
# 3   78644  Female     Loyal Customer   34  Business travel  Business
# 4   92713    Male     Loyal Customer   39  Business travel  Business
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0             2354             2                                  2
# 1             2855             2                                  2
# 2             1250             4                                  4
# 3               95             1                                  2
# 4             3276             5                                  2
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# 0               2  ...               2                       2
# ...

# %%
df2.isnull().sum()
# Out:
# Id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
df2['Gender']=df2['Gender'].map({'Male': 1, 'Female': 0})
df2['Customer Type']=df2['Customer Type'].map({'Loyal Customer': 1, 'disloyal Customer': 0})
df2['Type of Travel']=df2['Type of Travel'].map({'Business travel': 1, 'Personal Travel': 0})

# %%
df2 = pd.get_dummies(df2, columns=['Class'])

# %%
df2= df2.apply(lambda col: col.astype(int) if col.dtype == "bool" else col)

# %%
df2.head()
# Out:
#        Id  Gender  Customer Type  Age  Type of Travel  Flight Distance  \
# 0   46587       0              0   22               1             2354
# 1  124920       1              1   25               1             2855
# 2   18490       0              1   21               0             1250
# 3   78644       0              1   34               1               95
# 4   92713       1              1   39               1             3276
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             2                                  2               2
# 1             2                                  2               2
# 2             4                                  4               4
# 3             1                                  2               2
# 4             5                                  2               5
#
#    Gate location  ...  Leg room service  Baggage handling  Checkin service  \
# ...

# %%
X_test=df2.copy()

# %%
X_test.head()
# Out:
#        Id  Gender  Customer Type  Age  Type of Travel  Flight Distance  \
# 0   46587       0              0   22               1             2354
# 1  124920       1              1   25               1             2855
# 2   18490       0              1   21               0             1250
# 3   78644       0              1   34               1               95
# 4   92713       1              1   39               1             3276
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             2                                  2               2
# 1             2                                  2               2
# 2             4                                  4               4
# 3             1                                  2               2
# 4             5                                  2               5
#
#    Gate location  ...  Leg room service  Baggage handling  Checkin service  \
# ...

# %%
X_test=X_test.drop(['Gender','Id','Age','Class_Business','Class_Eco','Class_Eco Plus','Arrival Delay in Minutes','Departure/Arrival time convenient','Online boarding','Cleanliness','Checkin service','Leg room service','Ease of Online booking','Online support','On-board service'], axis=1)

# %%
test_prediction_11=tree.predict(X_test)

# %%
test_prediction_11
# Out:
# array(['dissatisfied', 'satisfied', 'satisfied', ..., 'dissatisfied',
#        'dissatisfied', 'dissatisfied'], dtype=object)

# %%
submission_11= pd.DataFrame({'ID' : df2['Id'],'satisfaction' :test_prediction_11})

# %%
filename="Tensor_Titans_11.csv"
submission_11.to_csv(filename, index= False)
print('Saved File' + filename)
# Out:
# Saved FileTensor_Titans_11.csv
